# %%
# Harbinger Package
# version 1.0.56

source("https://raw.githubusercontent.com/cefet-rj-dal/harbinger-examples/main/jupyter.R")

#loading Harbinger
load_library("daltoolbox") 
load_github("cefet-rj-dal/harbinger")
# Out:
# Loading required package: daltoolbox
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
#
# Attaching package: ‘daltoolbox’
#
#
# The following object is masked from ‘package:base’:
#
#     transform
#
#
# Loading required package: harbinger

# %%
#loading the example database
data(har_examples)
model <- hanr_arima()

# %%
#Using the time series 1 
dataset <- har_examples$example1
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 2 
dataset <- har_examples$example2
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 3 
dataset <- har_examples$example3
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 4 
dataset <- har_examples$example4
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 5 
dataset <- har_examples$example5
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 6 
dataset <- har_examples$example6
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 7 
dataset <- har_examples$example7
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 8 
dataset <- har_examples$example8
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 9 
dataset <- har_examples$example9
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 10
dataset <- har_examples$example10
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 11
dataset <- har_examples$example11
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# Don't know how to automatically pick scale for object of type <ts>. Defaulting
# to continuous.
# plot without title

# %%
#Using the time series 12
dataset <- har_examples$example12
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# Don't know how to automatically pick scale for object of type <ts>. Defaulting
# to continuous.
# plot without title

# %%
#Using the time series 13
dataset <- har_examples$example13
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# Don't know how to automatically pick scale for object of type <ts>. Defaulting
# to continuous.
# plot without title

# %%
#Using the time series 14
dataset <- har_examples$example14
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# Don't know how to automatically pick scale for object of type <ts>. Defaulting
# to continuous.
# plot without title

# %%
#Using the time series 15
dataset <- har_examples$example15
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 16
dataset <- har_examples$example16
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 17
dataset <- har_examples$example17
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title

# %%
#Using the time series 18
dataset <- har_examples$example18
model <- fit(hanr_arima(), dataset$serie)
detection <- detect(model, dataset$serie)
grf <- har_plot(model, dataset$serie, detection, dataset$event)
plot(grf)
# Out:
# plot without title
