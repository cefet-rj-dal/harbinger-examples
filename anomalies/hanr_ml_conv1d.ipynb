# %%
# Harbinger Package
# version 1.0.56

source("https://raw.githubusercontent.com/cefet-rj-dal/harbinger-examples/main/jupyter.R")

#loading Harbinger
load_library("daltoolbox") 
load_github("cefet-rj-dal/harbinger")
# Out:
# Loading required package: daltoolbox
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
#
# Attaching package: ‘daltoolbox’
#
#
# The following object is masked from ‘package:base’:
#
#     transform
#
#
# Loading required package: harbinger

# %%
#loading the example database
data(har_examples)

# %%
#Using the time series 1
dataset <- har_examples$example1
head(dataset)
# Out:
#   serie     event
# 1 1.0000000 FALSE
# 2 0.9689124 FALSE
# 3 0.8775826 FALSE
# 4 0.7316889 FALSE
# 5 0.5403023 FALSE
# 6 0.3153224 FALSE

# %%
#ploting serie #1
plot_ts(x = 1:length(dataset$serie), y = dataset$serie)
# Out:
# plot without title

# %%
# establishing conv1d method 
  model <- hanr_ml(har_conv1d(ts_norm_gminmax(), input_size=4, epochs=10000))

# %%
# fitting the model
  model <- fit(model, dataset$serie)

# %%
# making detections using hanr_ml with conv1d
  detection <- detect(model, dataset$serie)

# %%
# filtering detected events
  print(detection |> dplyr::filter(event==TRUE))
# Out:
#   idx event    type
# 1  24  TRUE anomaly
# 2  27  TRUE anomaly
# 3  49  TRUE anomaly
# 4  75  TRUE anomaly
# 5 100  TRUE anomaly

# %%
# evaluating the detections
  evaluation <- evaluate(model, detection$event, dataset$event)
  print(evaluation$confMatrix)
# Out:
#           event
# detection TRUE  FALSE
# TRUE      0     5
# FALSE     1     95

# %%
# ploting the results
  grf <- har_plot(model, dataset$serie, detection, dataset$event)
  plot(grf)
# Out:
# plot without title
